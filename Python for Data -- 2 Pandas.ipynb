# %%
import pandas as pd

# %%
#you can import like this and the keys become column names 

df1 = pd.DataFrame({
  'Product ID': [1, 2, 3, 4],'Product Name':['t-shirt', 't-shirt', 'skirt', 'skirt'], 'Color': ['blue', 'green', 'red', 'black']
  
})

print(df1)
# Out:
#    Product ID Product Name  Color
# 0           1      t-shirt   blue
# 1           2      t-shirt  green
# 2           3        skirt    red
# 3           4        skirt  black

# %%
#you can also pass in lists and define the column names

df2 = pd.DataFrame([
  [1, 'San Diego', 100],
  [2, 'Los Angeles', 120],[3, 'San Francisco', 90], [4, 'Sacramento', 115]
],
  columns=['Store ID', 'Location', 'Number of Employees'
  ])

print(df2)
# Out:
#    Store ID       Location  Number of Employees
# 0         1      San Diego                  100
# 1         2    Los Angeles                  120
# 2         3  San Francisco                   90
# 3         4     Sacramento                  115

# %%
# open a csv using pd.read_csv('sample.csv')

# save a csv using df.to_csv('new-csv-file.csv')

# %%
# df.head()
# df.info()

# %%
path = r'/Users/rachelallen/CareerFoundry Achievement 4/08-2022 Instacart Basket Analysis/02 Data/Original Data'

# %%
import os

# %%
df = pd.read_csv(os.path.join(path, 'customers.csv'))

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
#select a column like you would a key

first_name = df['First Name']

# %%
type(first_name)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
first_name
# Out:
# 0          Deborah
# 1         Patricia
# 2          Kenneth
# 3         Michelle
# 4              Ann
#             ...
# 206204        Lisa
# 206205      Jeremy
# 206206       Doris
# 206207        Rose
# 206208     Cynthia
# Name: First Name, Length: 206209, dtype: object

# %%
#double brackets select multiple columns inside double brackets not individual ones

full_name = df[['First Name', 'Surnam']]

# %%
full_name
# Out:
#        First Name    Surnam
# 0         Deborah  Esquivel
# 1        Patricia      Hart
# 2         Kenneth    Farley
# 3        Michelle     Hicks
# 4             Ann   Gilmore
# ...           ...       ...
# 206204       Lisa      Case
# 206205     Jeremy   Robbins
# 206206      Doris  Richmond
# 206207       Rose   Rollins
# 206208    Cynthia     Noble
#
# [206209 rows x 2 columns]

# %%
type(full_name)
# Out:
# pandas.core.frame.DataFrame

# %%
#save a row using df.iloc[zero indexed]

patricia = df.iloc[1]

# %%
patricia
# Out:
# user_id              33890
# First Name        Patricia
# Surnam                Hart
# Gender              Female
# STATE           New Mexico
# Age                     36
# date_joined       1/1/2017
# n_dependants             0
# fam_status          single
# income               59285
# Name: 1, dtype: object

# %%
# select mutltiple rows using df.iloc[1:4] or df.iloc[:4] or df.iloc[-4:] or whatever

row_sample = df.iloc[:4]

# %%
row_sample
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049

# %%
# select a subset df[df.MyColumnName == desired_column_value]

no_men = df[df.Gender == 'Male']

# %%
no_men.head()
# Out:
#    user_id First Name   Surnam Gender           STATE  Age date_joined  \
# 2    65803    Kenneth   Farley   Male           Idaho   35    1/1/2017
# 6   152052      Chris   Walton   Male         Montana   20    1/1/2017
# 7   168851     Joseph  Hickman   Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy     Vang   Male           Texas   47    1/1/2017
# 9    82820      Shawn    Chung   Male        Virginia   26    1/1/2017
#
#    n_dependants fam_status  income
# 2             2    married   99568
# 6             0     single   61746
# 7             0     single   63712
# 8             1    married  162432
# 9             2    married   32072

# %%
# you can use multiple statements using & or | in parens

new_york_ladies = df[(df.Gender == 'Female') & (df.STATE == 'New York')]

# %%
new_york_ladies
# Out:
#         user_id First Name      Surnam  Gender     STATE  Age date_joined  \
# 43       166899    Kathryn    Guerrero  Female  New York   56    1/1/2017
# 220      139665       Ruth  Cunningham  Female  New York   41    1/2/2017
# 314      126558     Janice      Hughes  Female  New York   18    1/3/2017
# 574      172713      Julie      Savage  Female  New York   77    1/4/2017
# 697       47814      Marie    Crawford  Female  New York   53    1/5/2017
# ...         ...        ...         ...     ...       ...  ...         ...
# 205931   131046  Christina    Friedman  Female  New York   59   3/31/2020
# 205938   149661      Irene        Lynn  Female  New York   75   3/31/2020
# 206022    12267    Carolyn      Kelley  Female  New York   72   3/31/2020
# 206088   159402    Deborah      Potter  Female  New York   75    4/1/2020
# 206208    80148    Cynthia       Noble  Female  New York   55    4/1/2020
#
#         n_dependants                        fam_status  income
# ...

# %%
nj_parents = df[(df.STATE == 'New Jersey') | (df.n_dependants > 2)]

# %%
nj_parents
# Out:
#         user_id First Name     Surnam  Gender         STATE  Age date_joined  \
# 0         26711    Deborah   Esquivel  Female      Missouri   48    1/1/2017
# 16         8794        Amy       Mack  Female      Nebraska   30    1/1/2017
# 28        86936   Kimberly     Monroe  Female        Oregon   57    1/1/2017
# 32       112664   Nicholas      Logan    Male    California   64    1/1/2017
# 35       127020       Judy    Barrett  Female          Ohio   35    1/1/2017
# ...         ...        ...        ...     ...           ...  ...         ...
# 206186   107955     Victor     Guzman    Male  Pennsylvania   41    4/1/2020
# 206191     7177    Russell  Zimmerman    Male   Mississippi   71    4/1/2020
# 206192    61888     Joshua     Guerra    Male    New Jersey   37    4/1/2020
# 206194   189337      Shawn       Wood    Male    New Jersey   56    4/1/2020
# 206205    49635     Jeremy    Robbins    Male        Hawaii   62    4/1/2020
#
#         n_dependants fam_status  income
# ...

# %%
# choose specific values in a column using isin
#df[df.name.isin(['Martha Jones',  'Rose Tyler',  'Amy Pond'])]

tri_state = df[df.STATE.isin(['New York', 'New Jersey', 'Pennsylvania'])]

# %%
tri_state
# Out:
#         user_id First Name     Surnam  Gender         STATE  Age date_joined  \
# 33       113616    Stephen    Murillo    Male  Pennsylvania   57    1/1/2017
# 43       166899    Kathryn   Guerrero  Female      New York   56    1/1/2017
# 71       163800      Keith  Frederick    Male  Pennsylvania   58    1/1/2017
# 83       119571    Matthew       Chan    Male      New York   58    1/1/2017
# 90       145236      Larry       Tang    Male  Pennsylvania   76    1/1/2017
# ...         ...        ...        ...     ...           ...  ...         ...
# 206186   107955     Victor     Guzman    Male  Pennsylvania   41    4/1/2020
# 206187   163443        Roy     Harvey    Male  Pennsylvania   37    4/1/2020
# 206192    61888     Joshua     Guerra    Male    New Jersey   37    4/1/2020
# 206194   189337      Shawn       Wood    Male    New Jersey   56    4/1/2020
# 206208    80148    Cynthia      Noble  Female      New York   55    4/1/2020
#
#         n_dependants fam_status  income
# ...

# %%
#our subset has a weird index -- it isn't in order

# df.reset_index()

tri_state.reset_index()
# Out:
#         index  user_id First Name     Surnam  Gender         STATE  Age  \
# 0          33   113616    Stephen    Murillo    Male  Pennsylvania   57
# 1          43   166899    Kathryn   Guerrero  Female      New York   56
# 2          71   163800      Keith  Frederick    Male  Pennsylvania   58
# 3          83   119571    Matthew       Chan    Male      New York   58
# 4          90   145236      Larry       Tang    Male  Pennsylvania   76
# ...       ...      ...        ...        ...     ...           ...  ...
# 12124  206186   107955     Victor     Guzman    Male  Pennsylvania   41
# 12125  206187   163443        Roy     Harvey    Male  Pennsylvania   37
# 12126  206192    61888     Joshua     Guerra    Male    New Jersey   37
# 12127  206194   189337      Shawn       Wood    Male    New Jersey   56
# 12128  206208    80148    Cynthia      Noble  Female      New York   55
#
#       date_joined  n_dependants fam_status  income
# 0        1/1/2017             2    married  118164
# ...

# %%
#or you can drop the old index 

tri_state.reset_index(drop = True)
# Out:
#        user_id First Name     Surnam  Gender         STATE  Age date_joined  \
# 0       113616    Stephen    Murillo    Male  Pennsylvania   57    1/1/2017
# 1       166899    Kathryn   Guerrero  Female      New York   56    1/1/2017
# 2       163800      Keith  Frederick    Male  Pennsylvania   58    1/1/2017
# 3       119571    Matthew       Chan    Male      New York   58    1/1/2017
# 4       145236      Larry       Tang    Male  Pennsylvania   76    1/1/2017
# ...        ...        ...        ...     ...           ...  ...         ...
# 12124   107955     Victor     Guzman    Male  Pennsylvania   41    4/1/2020
# 12125   163443        Roy     Harvey    Male  Pennsylvania   37    4/1/2020
# 12126    61888     Joshua     Guerra    Male    New Jersey   37    4/1/2020
# 12127   189337      Shawn       Wood    Male    New Jersey   56    4/1/2020
# 12128    80148    Cynthia      Noble  Female      New York   55    4/1/2020
#
#        n_dependants fam_status  income
# ...

# %%
# you can also use inplace = True

# %%
#select a column using df.columnname

tri_state.Surnam
# Out:
# 33          Murillo
# 43         Guerrero
# 71        Frederick
# 83             Chan
# 90             Tang
#             ...
# 206186       Guzman
# 206187       Harvey
# 206192       Guerra
# 206194         Wood
# 206208        Noble
# Name: Surnam, Length: 12129, dtype: object

# %%
# to add a column df['new column'] = ['value', 'value', 'value']

tri_state['Flag'] = True
# Out:
# /var/folders/sg/643_lsvj2pj89g1m5qn18t800000gp/T/ipykernel_3925/3979109971.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tri_state['Flag'] = True

# %%
tri_state.head()
# Out:
#     user_id First Name     Surnam  Gender         STATE  Age date_joined  \
# 33   113616    Stephen    Murillo    Male  Pennsylvania   57    1/1/2017
# 43   166899    Kathryn   Guerrero  Female      New York   56    1/1/2017
# 71   163800      Keith  Frederick    Male  Pennsylvania   58    1/1/2017
# 83   119571    Matthew       Chan    Male      New York   58    1/1/2017
# 90   145236      Larry       Tang    Male  Pennsylvania   76    1/1/2017
#
#     n_dependants fam_status  income  Flag
# 33             2    married  118164  True
# 43             2    married   64599  True
# 71             0     single  160461  True
# 83             2    married   98633  True
# 90             2    married   47486  True

# %%
tri_state['New'] = 'New'
# Out:
# /var/folders/sg/643_lsvj2pj89g1m5qn18t800000gp/T/ipykernel_3925/4048985318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tri_state['New'] = 'New'

# %%
tri_state.head()
# Out:
#     user_id First Name     Surnam  Gender         STATE  Age date_joined  \
# 33   113616    Stephen    Murillo    Male  Pennsylvania   57    1/1/2017
# 43   166899    Kathryn   Guerrero  Female      New York   56    1/1/2017
# 71   163800      Keith  Frederick    Male  Pennsylvania   58    1/1/2017
# 83   119571    Matthew       Chan    Male      New York   58    1/1/2017
# 90   145236      Larry       Tang    Male  Pennsylvania   76    1/1/2017
#
#     n_dependants fam_status  income  Flag  New
# 33             2    married  118164  True  New
# 43             2    married   64599  True  New
# 71             0     single  160461  True  New
# 83             2    married   98633  True  New
# 90             2    married   47486  True  New

# %%
#add a column based on a calculation

tri_state['Extra Kids'] = tri_state.n_dependants + 2
# Out:
# /var/folders/sg/643_lsvj2pj89g1m5qn18t800000gp/T/ipykernel_3925/1903166014.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tri_state['Extra Kids'] = tri_state.n_dependants + 2

# %%
tri_state.head()
# Out:
#     user_id First Name     Surnam  Gender         STATE  Age date_joined  \
# 33   113616    Stephen    Murillo    Male  Pennsylvania   57    1/1/2017
# 43   166899    Kathryn   Guerrero  Female      New York   56    1/1/2017
# 71   163800      Keith  Frederick    Male  Pennsylvania   58    1/1/2017
# 83   119571    Matthew       Chan    Male      New York   58    1/1/2017
# 90   145236      Larry       Tang    Male  Pennsylvania   76    1/1/2017
#
#     n_dependants fam_status  income  Flag  New  Extra Kids
# 33             2    married  118164  True  New           4
# 43             2    married   64599  True  New           4
# 71             0     single  160461  True  New           2
# 83             2    married   98633  True  New           4
# 90             2    married   47486  True  New           4

# %%
# can also use the syntax df['new column'] = df['old column'] + df['old column']

# %%
# use apply to change everythign in one column 
# df['Name'] = df.Name.apply(str.upper)

df['Surnam'] = df.Surnam.apply(str.upper)

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  ESQUIVEL  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      HART  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    FARLEY    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     HICKS  Female        Iowa   40    1/1/2017
# 4   130797        Ann   GILMORE  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df['Surnam'] = df.Surnam.apply(str.lower)

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
#create a new column

tri_state['Upper'] = tri_state.Surnam.apply(str.upper)
# Out:
# /var/folders/sg/643_lsvj2pj89g1m5qn18t800000gp/T/ipykernel_3925/1577457080.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tri_state['Upper'] = tri_state.Surnam.apply(str.upper)

# %%
tri_state.head()
# Out:
#     user_id First Name     Surnam  Gender         STATE  Age date_joined  \
# 33   113616    Stephen    Murillo    Male  Pennsylvania   57    1/1/2017
# 43   166899    Kathryn   Guerrero  Female      New York   56    1/1/2017
# 71   163800      Keith  Frederick    Male  Pennsylvania   58    1/1/2017
# 83   119571    Matthew       Chan    Male      New York   58    1/1/2017
# 90   145236      Larry       Tang    Male  Pennsylvania   76    1/1/2017
#
#     n_dependants fam_status  income  Flag  New  Extra Kids      Upper
# 33             2    married  118164  True  New           4    MURILLO
# 43             2    married   64599  True  New           4   GUERRERO
# 71             0     single  160461  True  New           2  FREDERICK
# 83             2    married   98633  True  New           4       CHAN
# 90             2    married   47486  True  New           4       TANG

# %%
# sudden stop to review lambda functions 

mylambda = lambda x: x[0]+x[-1]

print(mylambda('This is a string'))
# Out:
# Tg

# %%
mylambda = lambda x: (x * 2) + 3
print(mylambda(5))
# Out:
# 13

# %%
#using if in a lambda function

#lambda x: [OUTCOME IF TRUE] if [CONDITIONAL] else [OUTCOME IF FALSE]

# myfunction = lambda x: 40 + (x - 40) * 1.50 if x > 40 else x

# %%
mylambda2 = lambda x: 'Welcome to BattleCity!' if x >= 13 else 'You must be 13 or older'

# %%
mylambda2(14)
# Out:
# 'Welcome to BattleCity!'

# %%
mylambda2(10)
# Out:
# 'You must be 13 or older'

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
#just for a sample
# this would split a  name in half get_last_name = lambda x: x.split(' ')[-1]

# and this would apply it df['last_name'] = df.name.apply(get_last_name)

get_second_state = lambda x: x.split(' ')[-1]
df['half state'] = df.STATE.apply(get_second_state)

# %%
df.head(20)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %%
df['half state'].value_counts(dropna = False)
# Out:
# Dakota           8086
# Carolina         8086
# Virginia         8086
# California       4044
# Illinois         4044
# Alabama          4044
# Columbia         4044
# Hawaii           4044
# Arizona          4044
# Connecticut      4044
# Florida          4044
# Indiana          4044
# Arkansas         4044
# Alaska           4044
# Delaware         4044
# Colorado         4044
# Idaho            4044
# Georgia          4044
# Iowa             4044
# Massachusetts    4043
# Utah             4043
# Hampshire        4043
# Kentucky         4043
# Maryland         4043
# Michigan         4043
# Island           4043
# Mississippi      4043
# Jersey           4043
# Kansas           4043
# Minnesota        4043
# Tennessee        4043
# Oklahoma         4043
# York             4043
# Wisconsin        4043
# Washington       4043
# Louisiana        4043
# Montana          4043
# Texas            4043
# Ohio             4043
# Pennsylvania     4043
# Mexico           4043
# ...

# %%
# if you use .apply(axis = 1) it applies to a whole row
# df['Price with Tax'] = df.apply(lambda row: row['Price'] * 1.075 if row['Is taxed?'] == 'Yes' else row['Price'], axis=1)

#when you do the df['new column'] = df.apply(lambda function, axis = 1)

# %%
#df.columns = [] renames all columns 

df.columns = ['user_id', 'first_name', 'last_name', 'gender', 'state',	'age', 'date_joined', 'n_dependants',	'fam_status',	'income',	'half state']

# %%
df.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income half state
# 0             3    married  165665   Missouri
# 1             0     single   59285     Mexico
# 2             2    married   99568      Idaho
# 3             0     single   42049       Iowa
# 4             1    married   40374   Maryland

# %%
# .rename(columns = {'old': 'new'}, inplace = True) changes just one column

# df.rename(columns={ 'name': 'First Name', 'age': 'Age'}, inplace=True)

df.rename(columns = {'last_name': 'surname'}, inplace = True)

# %%
df.head()
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income half state
# 0             3    married  165665   Missouri
# 1             0     single   59285     Mexico
# 2             2    married   99568      Idaho
# 3             0     single   42049       Iowa
# 4             1    married   40374   Maryland

# %%
# create a salutation based on gender

genderlambda = lambda row: 'Dear Mr. ' + row.surname if row.gender == 'male' else 'Dear Ms. ' + row.surname

df['salutation'] = df.apply(genderlambda, axis = 1)

# %%
df.head()
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income half state         salutation
# 0             3    married  165665   Missouri  Dear Ms. Esquivel
# 1             0     single   59285     Mexico      Dear Ms. Hart
# 2             2    married   99568      Idaho    Dear Ms. Farley
# 3             0     single   42049       Iowa     Dear Ms. Hicks
# 4             1    married   40374   Maryland   Dear Ms. Gilmore

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# aggregates in pandas: df.column_name.command()

df.Age.mean()
# Out:
# 49.501646387888016

# %%
#mean	Average of all values in column
#std	Standard deviation
#median	Median
#max	Maximum value in column
#min	Minimum value in column
#count	Number of values in column
#nunique	Number of unique values in column
#unique	List of unique values in column

df.STATE.nunique()
# Out:
# 51

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.Age.std()
# Out:
# 18.480962407297998

# %%
df.Age.median()
# Out:
# 49.0

# %%
df.Age.max()
# Out:
# 81

# %%
df.Age.min()
# Out:
# 18

# %%
df.user_id.count()
# Out:
# 206209

# %%
# df.groupby('column1').column2.measurement() for example average scores per student

df.groupby('STATE').Age.mean()
# Out:
# STATE
# Alabama                 49.614491
# Alaska                  49.471068
# Arizona                 49.504698
# Arkansas                49.432987
# California              49.543274
# Colorado                49.159496
# Connecticut             49.437685
# Delaware                49.348665
# District of Columbia    49.465875
# Florida                 49.051434
# Georgia                 49.569980
# Hawaii                  49.540059
# Idaho                   49.351385
# Illinois                49.319980
# Indiana                 49.705737
# Iowa                    49.919634
# Kansas                  49.356419
# Kentucky                49.821420
# Louisiana               49.410586
# Maine                   49.380658
# Maryland                49.418748
# Massachusetts           49.470690
# Michigan                49.869404
# Minnesota               49.778877
# Mississippi             49.514717
# Missouri                49.283206
# Montana                 49.878803
# ...

# %%
# add .reset_index()

# %%
df.groupby('STATE').Age.max().reset_index()
# Out:
#                    STATE  Age
# 0                Alabama   81
# 1                 Alaska   81
# 2                Arizona   81
# 3               Arkansas   81
# 4             California   81
# 5               Colorado   81
# 6            Connecticut   81
# 7               Delaware   81
# 8   District of Columbia   81
# 9                Florida   81
# 10               Georgia   81
# 11                Hawaii   81
# 12                 Idaho   81
# 13              Illinois   81
# 14               Indiana   81
# 15                  Iowa   81
# 16                Kansas   81
# 17              Kentucky   81
# 18             Louisiana   81
# 19                 Maine   81
# 20              Maryland   81
# 21         Massachusetts   81
# 22              Michigan   81
# 23             Minnesota   81
# 24           Mississippi   81
# 25              Missouri   81
# 26               Montana   81
# 27              Nebraska   81
# 28                Nevada   81
# 29         New Hampshire   81
# ...

# %%
#use lambda function to create a percentile

#high_earners = df.groupby('category').wage.apply(lambda x: np.percentile(x, 75)).reset_index()

import numpy as np
oldest_people = df.groupby('STATE').Age.apply(lambda x: np.percentile(x, 75)).reset_index()

# %%
oldest_people
# Out:
#                    STATE   Age
# 0                Alabama  65.0
# 1                 Alaska  66.0
# 2                Arizona  65.0
# 3               Arkansas  66.0
# 4             California  66.0
# 5               Colorado  65.0
# 6            Connecticut  65.0
# 7               Delaware  66.0
# 8   District of Columbia  65.0
# 9                Florida  65.0
# 10               Georgia  66.0
# 11                Hawaii  65.0
# 12                 Idaho  65.0
# 13              Illinois  65.0
# 14               Indiana  66.0
# 15                  Iowa  66.0
# 16                Kansas  65.0
# 17              Kentucky  66.0
# 18             Louisiana  65.0
# 19                 Maine  66.0
# 20              Maryland  66.0
# 21         Massachusetts  65.0
# 22              Michigan  65.0
# 23             Minnesota  66.0
# 24           Mississippi  66.0
# 25              Missouri  65.0
# 26               Montana  66.0
# 27              Nebraska  65.0
# 28                Nevada  66.0
# ...

# %%
# group by multiple columns
# df.groupby(['Location', 'Day of Week'])['Total Sales'].mean().reset_index()

double_agg = df.groupby(['STATE', 'Gender'])['income'].mean().reset_index()

# %%
double_agg
# Out:
#              STATE  Gender        income
# 0          Alabama  Female  93752.645729
# 1          Alabama    Male  94106.242941
# 2           Alaska  Female  94259.190382
# 3           Alaska    Male  94574.538727
# 4          Arizona  Female  94120.057443
# ..             ...     ...           ...
# 97   West Virginia    Male  93619.482908
# 98       Wisconsin  Female  95584.615499
# 99       Wisconsin    Male  92951.786207
# 100        Wyoming  Female  95422.501728
# 101        Wyoming    Male  95152.958375
#
# [102 rows x 3 columns]

# %%
# pivot tables in pandas 
# df.pivot(columns='ColumnToPivot', index='ColumnToBeRows', values='ColumnToBeValues')

pivot_table = double_agg.pivot(columns = 'STATE', index = 'Gender', values = 'income').reset_index()

# %%
pivot_table
# Out:
# STATE  Gender       Alabama        Alaska       Arizona      Arkansas  \
# 0      Female  93752.645729  94259.190382  94120.057443  94980.709661
# 1        Male  94106.242941  94574.538727  95828.831048  94257.449902
#
# STATE    California      Colorado   Connecticut      Delaware  \
# 0      94716.360298  94834.274798  95067.183316  93888.914534
# 1      95120.917201  93862.784816  95654.133682  94130.396858
#
# STATE  District of Columbia  ...  South Dakota     Tennessee         Texas  \
# 0              94872.380344  ...  94999.877335  95595.642928  93742.025063
# 1              95047.525635  ...  95841.684772  92785.188026  95336.875488
#
# STATE          Utah       Vermont      Virginia    Washington  West Virginia  \
# 0      96311.221453  95335.199588  96382.822300  95460.639041   95603.966429
# 1      93372.505941  96167.624583  94169.632743  94509.203431   93619.482908
#
# STATE     Wisconsin       Wyoming
# 0      95584.615499  95422.501728
# ...

# %%
pivot_table2 = double_agg.pivot(columns = 'Gender', index = 'STATE', values = 'income').reset_index()

# %%
pivot_table2
# Out:
# Gender                 STATE        Female          Male
# 0                    Alabama  93752.645729  94106.242941
# 1                     Alaska  94259.190382  94574.538727
# 2                    Arizona  94120.057443  95828.831048
# 3                   Arkansas  94980.709661  94257.449902
# 4                 California  94716.360298  95120.917201
# 5                   Colorado  94834.274798  93862.784816
# 6                Connecticut  95067.183316  95654.133682
# 7                   Delaware  93888.914534  94130.396858
# 8       District of Columbia  94872.380344  95047.525635
# 9                    Florida  93461.649585  92685.793484
# 10                   Georgia  94749.606794  92546.640171
# 11                    Hawaii  95514.491534  94405.519646
# 12                     Idaho  93171.535035  93746.314272
# 13                  Illinois  93437.042605  95350.990509
# 14                   Indiana  95564.303734  95416.450533
# ...

# %%
#If the column ad_click_timestamp is not null, then someone actually clicked on the ad that was displayed.

#Create a new column called is_click, which is True if ad_click_timestamp is not null and False otherwise.

#ad_clicks['is_click'] = ~ad_clicks.ad_click_timestamp.isnull()
